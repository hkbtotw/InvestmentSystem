# %%
import pandas as pd

df = pd.read_excel (r'C:\Users\kira\Downloads\Fund_History_20210208_v1.0.0.xlsx', sheet_name='k-usa-a(a)')

dfIn=df.set_index(['Date']).copy()
print (dfIn)
dfIn.plot()
# Out:
#             Price
# Date
# 2019-09-16  15.35
# 2019-09-23  15.20
# 2019-09-30  14.94
# 2019-10-07  15.06
# 2019-10-14  15.07
# ...           ...
# 2021-01-04  26.49
# 2021-01-11  26.58
# 2021-01-18  26.47
# 2021-01-25  26.45
# 2021-02-01  26.63
#
# [73 rows x 1 columns]

# %%
#dfIn=dfIn.resample('d',convention='start').asfreq()
dfIn=dfIn.resample('d',convention='start').interpolate().add_suffix('_inter')
dfIn.to_csv('Fund_History_20210208_v2.0.0.csv')

# %%
import matplotlib.pyplot as plt

dfIn.plot()
